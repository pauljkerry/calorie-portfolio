# %%
import pandas as pd
import numpy as np
import sys, os

sys.path.append(os.path.abspath(".."))

import src.utils.eda as eda

# %%
# 生データの読み込み
train_data = pd.read_csv("../input/train.csv")
test_data = pd.read_csv("../input/test.csv")

# %%
# データの概要の確認
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          750000 non-null  int64
#  1   Sex         750000 non-null  object
#  2   Age         750000 non-null  int64
#  3   Height      750000 non-null  float64
#  4   Weight      750000 non-null  float64
#  5   Duration    750000 non-null  float64
#  6   Heart_Rate  750000 non-null  float64
#  7   Body_Temp   750000 non-null  float64
#  8   Calories    750000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 51.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          250000 non-null  int64
#  1   Sex         250000 non-null  object
#  2   Age         250000 non-null  int64
#  3   Height      250000 non-null  float64
#  4   Weight      250000 non-null  float64
#  5   Duration    250000 non-null  float64
#  6   Heart_Rate  250000 non-null  float64
#  7   Body_Temp   250000 non-null  float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 15.3+ MB

# %%
# 欠損値の確認
eda.check_missing_info(train_data)
eda.check_missing_info(test_data)
# Out:
# No missing
# No missing

# %%
# カテゴリ変数の各水準の頻度を確認
eda.plot_category_freq(train_data)
eda.plot_category_freq(test_data)
# Out:
# Sex        female    male
# Count      375721  374279
# Ratio (%)  50.10%  49.90%
# Sex        female    male
# Count      125281  124719
# Ratio (%)  50.11%  49.89%

# %%
# 数値変数の分布を確認
eda.plot_numerical_distribution(train_data)
eda.plot_numerical_distribution(test_data)
# Out:
#                count           mean            std    min       1%        25%  \
# Age         750000.0      41.420404      15.175049   20.0    20.00      28.00
# Body_Temp   750000.0      40.036253       0.779875   37.1    37.70      39.60
# Calories    750000.0      88.282781      62.395349    1.0     3.00      34.00
# Duration    750000.0      15.421015       8.354095    1.0     1.00       8.00
# Heart_Rate  750000.0      95.483995       9.449845   67.0    76.00      88.00
# Height      750000.0     174.697685      12.824496  126.0   150.00     164.00
# Weight      750000.0      75.145668      13.982704   36.0    51.00      63.00
# id          750000.0  374999.500000  216506.495284    0.0  7499.99  187499.75
#
#                  50%        75%        99%       max
# Age             40.0      52.00      77.00      79.0
# Body_Temp       40.3      40.70      41.10      41.5
# Calories        77.0     136.00     237.00     314.0
# Duration        15.0      23.00      30.00      30.0
# Heart_Rate      95.0     103.00     115.00     128.0
# Height         174.0     185.00     201.00     222.0
# Weight          74.0      87.00     103.00     132.0
# id          374999.5  562499.25  742499.01  749999.0
#                count           mean           std       min         1%  \
# Age         250000.0      41.452464     15.177769      20.0      20.00
# Body_Temp   250000.0      40.036093      0.778448      37.1      37.70
# Duration    250000.0      15.415428      8.349133       1.0       1.00
# Heart_Rate  250000.0      95.479084      9.450161      67.0      76.00
# Height      250000.0     174.725624     12.822039     127.0     150.00
# Weight      250000.0      75.147712     13.979513      39.0      51.00
# id          250000.0  874999.500000  72168.927986  750000.0  752499.99
#
#                   25%       50%        75%        99%       max
# Age             28.00      40.0      52.00      76.00      79.0
# Body_Temp       39.60      40.3      40.60      41.10      41.5
# Duration         8.00      15.0      23.00      30.00      30.0
# Heart_Rate      88.00      95.0     103.00     115.00     128.0
# Height         164.00     174.0     185.00     201.00     219.0
# Weight          63.00      74.0      87.00     103.00     126.0
# id          812499.75  874999.5  937499.25  997499.01  999999.0

# %%
# train dataの数値変数と質的変数の関係の分布
eda.plot_kde_and_boxplot(train_data)

# %%
# test dataの数値変数と質的変数の関係の分布
eda.plot_kde_and_boxplot(test_data)

# %%
# 数値データの相関係数を確認
eda.show_corr_heatmap(train_data)
eda.show_corr_heatmap(test_data)
