# %%
import sys, os
import pandas as pd
import optuna
import importlib

sys.path.append(os.path.abspath(".."))

import src.models.cb.cb_cv_trainer as cv
import src.utils.optuna_visualizer as opv

# %%
# データの読み込み
storage = "postgresql://optuna_user:optuna_pass@localhost:5432/optuna_db"

tr_df4 = pd.read_csv("../artifacts/features/tr_df4.csv")
test_df4 = pd.read_csv("../artifacts/features/test_df4.csv")

cat_cols = [
    "Tem", "Hum", "Moi", "N", "K", "P", "Soil", "Crop"
]

# %%
# cvの性能実験
params = {
    'iterations': 4200,
    'depth': 9,
    'learning_rate': 0.012311151478845978, 
    'l2_leaf_reg': 0.01182407665426616, 
    'random_strength': 0.2351783662718401, 
    'bagging_temperature': 0.8517467698288006, 
    'border_count': 129, 
    'min_data_in_leaf': 75, 
    'grow_policy': 'Depthwise',
    'loss_function': 'MultiClass',
}

trainer = cv.CBCVTrainer(params=params, cat_cols=cat_cols)
trainer.fit_one_fold(tr_df4)
# Out:
# 0:	learn: 1.9456712	test: 1.9457496	best: 1.9457496 (0)	total: 249ms	remaining: 17m 26s
# 100:	learn: 1.9311474	test: 1.9377945	best: 1.9377945 (100)	total: 6.89s	remaining: 4m 39s
# 200:	learn: 1.9214290	test: 1.9343419	best: 1.9343419 (200)	total: 13.4s	remaining: 4m 25s
# 300:	learn: 1.9129170	test: 1.9319204	best: 1.9319204 (300)	total: 18.9s	remaining: 4m 5s
# 400:	learn: 1.9053541	test: 1.9301342	best: 1.9301342 (400)	total: 25s	remaining: 3m 56s
# 500:	learn: 1.8995870	test: 1.9290213	best: 1.9290213 (500)	total: 30.1s	remaining: 3m 42s
# 600:	learn: 1.8948662	test: 1.9281369	best: 1.9281369 (600)	total: 35s	remaining: 3m 29s
# 700:	learn: 1.8909586	test: 1.9275855	best: 1.9275855 (700)	total: 39.5s	remaining: 3m 17s
# 800:	learn: 1.8868283	test: 1.9270452	best: 1.9270452 (800)	total: 43.6s	remaining: 3m 4s
# 900:	learn: 1.8827639	test: 1.9265904	best: 1.9265904 (900)	total: 48.3s	remaining: 2m 56s
# ...
