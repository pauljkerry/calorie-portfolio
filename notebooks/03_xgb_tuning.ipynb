# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
import optuna

sys.path.append(os.path.abspath(".."))

import src.models.xgb.xgb_optuna_optimizer as op
import src.utils.telegram as te

# %%
# データの読み込み
env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=env_path)
url = os.environ.get("OPTUNA_STORAGE_URL")

l1_tr_df3 = pd.read_parquet("../artifacts/features/l1/l1_tr_df3.parquet")

# %%
# tuning
objective = op.create_objective(
    l1_tr_df3,
    early_stopping_rounds=100,
    tree_method="gpu_hist",
    n_jobs=10
)

op.run_optuna_search(
    objective,
    n_trials=10,
    n_jobs=1,
    study_name="l1_xgb_v1",
    storage=url,
    sampler=optuna.samplers.TPESampler(seed=42, n_startup_trials=10)
)
te.send_telegram_message("Training complete!")
# Out:
# [I 2025-07-28 16:12:02,823] Using an existing study with name 'l1_xgb_v1' instead of creating a new one.
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0]	train-rmse:0.94287	eval-rmse:0.94196
# [100]	train-rmse:0.12403	eval-rmse:0.12115
# [200]	train-rmse:0.06139	eval-rmse:0.06096
# [300]	train-rmse:0.06008	eval-rmse:0.06034
# [358]	train-rmse:0.06006	eval-rmse:0.06040
# Training time: 00:00:02
# Train rmse: 0.06018
# Valid rmse: 0.06030
# [I 2025-07-28 16:12:05,026] Trial 61 finished with value: 0.06030211852701282 and parameters: {'learning_rate': 0.021425094779472156, 'max_depth': 9, 'min_child_weight': 24.21837958350173, 'colsample_bytree': 1.0, 'subsample': 0.7711133715555654, 'reg_alpha': 3.734350509981003, 'reg_lambda': 2.6165761381054975}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.93607	eval-rmse:0.93513
# [100]	train-rmse:0.08013	eval-rmse:0.07799
# [200]	train-rmse:0.06020	eval-rmse:0.06032
# [300]	train-rmse:0.06008	eval-rmse:0.06040
# Training time: 00:00:00
# Train rmse: 0.06019
# Valid rmse: 0.06032
# [I 2025-07-28 16:12:06,122] Trial 62 finished with value: 0.06032002986193884 and parameters: {'learning_rate': 0.028566288611327862, 'max_depth': 5, 'min_child_weight': 23.590337209772734, 'colsample_bytree': 1.0, 'subsample': 0.8140764458930849, 'reg_alpha': 19.567975821491007, 'reg_lambda': 0.7196329096470042}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.93655	eval-rmse:0.93562
# [100]	train-rmse:0.08188	eval-rmse:0.07968
# [200]	train-rmse:0.06022	eval-rmse:0.06032
# [300]	train-rmse:0.06008	eval-rmse:0.06040
# [304]	train-rmse:0.06008	eval-rmse:0.06040
# Training time: 00:00:00
# Train rmse: 0.06019
# Valid rmse: 0.06032
# [I 2025-07-28 16:12:07,196] Trial 63 finished with value: 0.06032121278160083 and parameters: {'learning_rate': 0.028171262357392996, 'max_depth': 4, 'min_child_weight': 33.446184388100185, 'colsample_bytree': 1.0, 'subsample': 0.844497622502534, 'reg_alpha': 19.471596714182695, 'reg_lambda': 0.1762583471125039}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.93578	eval-rmse:0.93487
# [100]	train-rmse:0.08014	eval-rmse:0.07814
# [200]	train-rmse:0.06019	eval-rmse:0.06034
# [300]	train-rmse:0.06008	eval-rmse:0.06042
# [301]	train-rmse:0.06008	eval-rmse:0.06042
# Training time: 00:00:00
# Train rmse: 0.06018
# Valid rmse: 0.06034
# [I 2025-07-28 16:12:08,095] Trial 64 finished with value: 0.06033603500141856 and parameters: {'learning_rate': 0.029458932410410657, 'max_depth': 3, 'min_child_weight': 26.293791231397798, 'colsample_bytree': 1.0, 'subsample': 0.7955333148666703, 'reg_alpha': 9.770488519235697, 'reg_lambda': 4.057553865223632}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.93809	eval-rmse:0.93716
# [100]	train-rmse:0.08853	eval-rmse:0.08612
# [200]	train-rmse:0.06025	eval-rmse:0.06031
# [300]	train-rmse:0.06006	eval-rmse:0.06040
# [310]	train-rmse:0.06006	eval-rmse:0.06040
# Training time: 00:00:00
# Train rmse: 0.06018
# Valid rmse: 0.06030
# [I 2025-07-28 16:12:09,197] Trial 65 finished with value: 0.06030312488807953 and parameters: {'learning_rate': 0.026432896689284772, 'max_depth': 5, 'min_child_weight': 30.38855068169466, 'colsample_bytree': 1.0, 'subsample': 0.7579178144028043, 'reg_alpha': 6.2049861467428755, 'reg_lambda': 1.009450782556461}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.94436	eval-rmse:0.94345
# [100]	train-rmse:0.14129	eval-rmse:0.13839
# [200]	train-rmse:0.06272	eval-rmse:0.06198
# [300]	train-rmse:0.06014	eval-rmse:0.06032
# [386]	train-rmse:0.06007	eval-rmse:0.06038
# Training time: 00:00:01
# Train rmse: 0.06018
# Valid rmse: 0.06031
# [I 2025-07-28 16:12:10,596] Trial 66 finished with value: 0.06031260841085182 and parameters: {'learning_rate': 0.0198893297596812, 'max_depth': 6, 'min_child_weight': 20.646542799438226, 'colsample_bytree': 1.0, 'subsample': 0.7394136709594992, 'reg_alpha': 13.996205089199815, 'reg_lambda': 1.8433522650656526}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.93571	eval-rmse:0.93477
# [100]	train-rmse:0.07834	eval-rmse:0.07629
# [200]	train-rmse:0.06012	eval-rmse:0.06031
# [289]	train-rmse:0.06006	eval-rmse:0.06042
# Training time: 00:00:00
# Train rmse: 0.06018
# Valid rmse: 0.06031
# [I 2025-07-28 16:12:11,549] Trial 67 finished with value: 0.06030550690833105 and parameters: {'learning_rate': 0.029047584470691487, 'max_depth': 4, 'min_child_weight': 9.230015460312316, 'colsample_bytree': 1.0, 'subsample': 0.8865814440910987, 'reg_alpha': 1.9065862850505604, 'reg_lambda': 7.696779812070235}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.93729	eval-rmse:0.93636
# [100]	train-rmse:0.08497	eval-rmse:0.08266
# [200]	train-rmse:0.06023	eval-rmse:0.06031
# [300]	train-rmse:0.06007	eval-rmse:0.06039
# [303]	train-rmse:0.06007	eval-rmse:0.06039
# Training time: 00:00:01
# Train rmse: 0.06020
# Valid rmse: 0.06031
# [I 2025-07-28 16:12:12,884] Trial 68 finished with value: 0.06031015715913719 and parameters: {'learning_rate': 0.027275656022569185, 'max_depth': 10, 'min_child_weight': 34.62148230337803, 'colsample_bytree': 1.0, 'subsample': 0.8566624988944583, 'reg_alpha': 14.43922808007895, 'reg_lambda': 0.7828393052574956}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.94700	eval-rmse:0.94609
# [100]	train-rmse:0.17943	eval-rmse:0.17647
# [200]	train-rmse:0.06750	eval-rmse:0.06612
# [300]	train-rmse:0.06036	eval-rmse:0.06035
# [400]	train-rmse:0.06008	eval-rmse:0.06036
# [428]	train-rmse:0.06007	eval-rmse:0.06037
# Training time: 00:00:01
# Train rmse: 0.06019
# Valid rmse: 0.06031
# [I 2025-07-28 16:12:14,566] Trial 69 finished with value: 0.06030665272459696 and parameters: {'learning_rate': 0.017135028778785626, 'max_depth': 6, 'min_child_weight': 40.08356589118583, 'colsample_bytree': 1.0, 'subsample': 0.543304449362793, 'reg_alpha': 8.466675137365227, 'reg_lambda': 0.2942765073467154}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:0.93972	eval-rmse:0.93879
# [100]	train-rmse:0.09795	eval-rmse:0.09533
# [200]	train-rmse:0.06042	eval-rmse:0.06037
# [300]	train-rmse:0.06006	eval-rmse:0.06039
# [322]	train-rmse:0.06006	eval-rmse:0.06040
# Training time: 00:00:01
# Train rmse: 0.06018
# Valid rmse: 0.06030
# [I 2025-07-28 16:12:15,921] Trial 70 finished with value: 0.06030259514427512 and parameters: {'learning_rate': 0.024706002421659063, 'max_depth': 7, 'min_child_weight': 45.17593564198688, 'colsample_bytree': 1.0, 'subsample': 0.8295516870019861, 'reg_alpha': 3.716327403661722, 'reg_lambda': 1.3329045857148363}. Best is trial 44 with value: 0.06016451525149665.
# ✅ Message sent successfully.
