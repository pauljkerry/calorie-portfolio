# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
import optuna

sys.path.append(os.path.abspath(".."))

import src.models.xgb.xgb_optuna_optimizer as op
import src.utils.telegram as te

# %%
# データの読み込み
env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=env_path)
url = os.environ.get("OPTUNA_STORAGE_URL")

l1_tr_df3 = pd.read_parquet("../artifacts/features/l1/l1_tr_df3.parquet")

# %%
# tuning
objective = op.create_objective(
    l1_tr_df3,
    early_stopping_rounds=100,
    tree_method="gpu_hist",
    n_jobs=10
)

op.run_optuna_search(
    objective,
    n_trials=10,
    n_jobs=1,
    study_name="l1_xgb_v1",
    storage=url,
    sampler=optuna.samplers.TPESampler(seed=42, n_startup_trials=10)
)
te.send_telegram_message("Training complete!")
# Out:
# [I 2025-07-28 01:36:47,133] Using an existing study with name 'l1_xgb_v1' instead of creating a new one.
#   0%|          | 0/10 [00:00<?, ?it/s]
# [0]	train-rmse:3.67881	eval-rmse:3.67853
# [100]	train-rmse:0.35417	eval-rmse:0.35537
# [200]	train-rmse:0.06884	eval-rmse:0.06939
# [300]	train-rmse:0.06040	eval-rmse:0.06034
# [400]	train-rmse:0.06032	eval-rmse:0.06018
# [500]	train-rmse:0.06032	eval-rmse:0.06018
# [600]	train-rmse:0.06032	eval-rmse:0.06018
# [687]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:04
# Train rmse: 0.06032
# Valid rmse: 0.06017
# [I 2025-07-28 01:36:52,200] Trial 51 finished with value: 0.06017481967591748 and parameters: {'learning_rate': 0.023286264905863434, 'max_depth': 10, 'min_child_weight': 40.04989034857968, 'colsample_bytree': 1.0, 'subsample': 0.6573635410181728, 'reg_alpha': 1.4598613761540122, 'reg_lambda': 3.454013068456216}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.66901	eval-rmse:3.66874
# [100]	train-rmse:0.27355	eval-rmse:0.27475
# [200]	train-rmse:0.06342	eval-rmse:0.06371
# [300]	train-rmse:0.06034	eval-rmse:0.06024
# [400]	train-rmse:0.06032	eval-rmse:0.06018
# [500]	train-rmse:0.06032	eval-rmse:0.06018
# [600]	train-rmse:0.06032	eval-rmse:0.06018
# [700]	train-rmse:0.06032	eval-rmse:0.06018
# [800]	train-rmse:0.06032	eval-rmse:0.06018
# [900]	train-rmse:0.06032	eval-rmse:0.06018
# [918]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:03
# Train rmse: 0.06032
# Valid rmse: 0.06018
# [I 2025-07-28 01:36:56,177] Trial 52 finished with value: 0.06017568850937097 and parameters: {'learning_rate': 0.025885322058054973, 'max_depth': 13, 'min_child_weight': 33.20309298976437, 'colsample_bytree': 1.0, 'subsample': 0.5650221738682297, 'reg_alpha': 5.0722259460426, 'reg_lambda': 0.476804900974532}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.65685	eval-rmse:3.65659
# [100]	train-rmse:0.20041	eval-rmse:0.20157
# [200]	train-rmse:0.06121	eval-rmse:0.06130
# [300]	train-rmse:0.06033	eval-rmse:0.06020
# [400]	train-rmse:0.06033	eval-rmse:0.06018
# [500]	train-rmse:0.06033	eval-rmse:0.06018
# [600]	train-rmse:0.06033	eval-rmse:0.06018
# [700]	train-rmse:0.06033	eval-rmse:0.06018
# [718]	train-rmse:0.06033	eval-rmse:0.06018
# Training time: 00:00:02
# Train rmse: 0.06033
# Valid rmse: 0.06018
# [I 2025-07-28 01:36:58,483] Trial 53 finished with value: 0.06017815252367451 and parameters: {'learning_rate': 0.029122358568395942, 'max_depth': 11, 'min_child_weight': 29.673938862777923, 'colsample_bytree': 1.0, 'subsample': 0.5251276151419095, 'reg_alpha': 11.793248472035751, 'reg_lambda': 1.0183012545754624}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.71302	eval-rmse:3.71273
# [100]	train-rmse:0.89112	eval-rmse:0.89205
# [200]	train-rmse:0.22153	eval-rmse:0.22271
# [300]	train-rmse:0.07917	eval-rmse:0.07994
# [400]	train-rmse:0.06160	eval-rmse:0.06174
# [500]	train-rmse:0.06040	eval-rmse:0.06033
# [600]	train-rmse:0.06033	eval-rmse:0.06021
# [700]	train-rmse:0.06032	eval-rmse:0.06019
# [800]	train-rmse:0.06032	eval-rmse:0.06018
# [900]	train-rmse:0.06032	eval-rmse:0.06018
# [1000]	train-rmse:0.06032	eval-rmse:0.06018
# [1100]	train-rmse:0.06032	eval-rmse:0.06018
# [1136]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:03
# Train rmse: 0.06032
# Valid rmse: 0.06018
# [I 2025-07-28 01:37:02,567] Trial 54 finished with value: 0.06017659555644456 and parameters: {'learning_rate': 0.01419930818067105, 'max_depth': 9, 'min_child_weight': 44.871658977816395, 'colsample_bytree': 1.0, 'subsample': 0.596323175000364, 'reg_alpha': 7.799131914836514, 'reg_lambda': 2.022545441310493}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.66134	eval-rmse:3.66108
# [100]	train-rmse:0.22426	eval-rmse:0.22547
# [200]	train-rmse:0.06168	eval-rmse:0.06184
# [300]	train-rmse:0.06033	eval-rmse:0.06020
# [400]	train-rmse:0.06032	eval-rmse:0.06018
# [500]	train-rmse:0.06032	eval-rmse:0.06018
# [600]	train-rmse:0.06032	eval-rmse:0.06018
# [700]	train-rmse:0.06032	eval-rmse:0.06018
# [726]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:02
# Train rmse: 0.06032
# Valid rmse: 0.06017
# [I 2025-07-28 01:37:05,442] Trial 55 finished with value: 0.06017490887428876 and parameters: {'learning_rate': 0.027921577245445278, 'max_depth': 8, 'min_child_weight': 38.06649335437047, 'colsample_bytree': 1.0, 'subsample': 0.5567417622128051, 'reg_alpha': 4.351995096764241, 'reg_lambda': 0.2015016591594736}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.65362	eval-rmse:3.65335
# [100]	train-rmse:0.18497	eval-rmse:0.18612
# [200]	train-rmse:0.06097	eval-rmse:0.06102
# [300]	train-rmse:0.06033	eval-rmse:0.06020
# [400]	train-rmse:0.06033	eval-rmse:0.06019
# [500]	train-rmse:0.06033	eval-rmse:0.06018
# [600]	train-rmse:0.06033	eval-rmse:0.06018
# [700]	train-rmse:0.06033	eval-rmse:0.06018
# [800]	train-rmse:0.06033	eval-rmse:0.06018
# [900]	train-rmse:0.06033	eval-rmse:0.06018
# [918]	train-rmse:0.06033	eval-rmse:0.06018
# Training time: 00:00:02
# Train rmse: 0.06033
# Valid rmse: 0.06018
# [I 2025-07-28 01:37:08,251] Trial 56 finished with value: 0.06018007671773026 and parameters: {'learning_rate': 0.029987248772831022, 'max_depth': 15, 'min_child_weight': 50.394079579276145, 'colsample_bytree': 1.0, 'subsample': 0.5455829385679591, 'reg_alpha': 13.598525537460835, 'reg_lambda': 4.706210584432749}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.72306	eval-rmse:3.72277
# [100]	train-rmse:1.16934	eval-rmse:1.17020
# [200]	train-rmse:0.37131	eval-rmse:0.37251
# [300]	train-rmse:0.12984	eval-rmse:0.13098
# [400]	train-rmse:0.07029	eval-rmse:0.07089
# [500]	train-rmse:0.06137	eval-rmse:0.06150
# [600]	train-rmse:0.06042	eval-rmse:0.06037
# [700]	train-rmse:0.06033	eval-rmse:0.06021
# [800]	train-rmse:0.06032	eval-rmse:0.06019
# [900]	train-rmse:0.06032	eval-rmse:0.06018
# [1000]	train-rmse:0.06032	eval-rmse:0.06018
# [1100]	train-rmse:0.06032	eval-rmse:0.06018
# [1137]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:05
# Train rmse: 0.06032
# Valid rmse: 0.06018
# [I 2025-07-28 01:37:14,068] Trial 57 finished with value: 0.06017653832946872 and parameters: {'learning_rate': 0.011527370862868397, 'max_depth': 12, 'min_child_weight': 41.64545709318981, 'colsample_bytree': 1.0, 'subsample': 0.5841717712554697, 'reg_alpha': 0.8393446864817733, 'reg_lambda': 0.08433664386312248}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.69815	eval-rmse:3.69786
# [100]	train-rmse:0.59610	eval-rmse:0.59715
# [200]	train-rmse:0.11297	eval-rmse:0.11400
# [300]	train-rmse:0.06233	eval-rmse:0.06254
# [400]	train-rmse:0.06039	eval-rmse:0.06031
# [500]	train-rmse:0.06033	eval-rmse:0.06020
# [600]	train-rmse:0.06033	eval-rmse:0.06019
# [700]	train-rmse:0.06032	eval-rmse:0.06018
# [800]	train-rmse:0.06032	eval-rmse:0.06018
# [900]	train-rmse:0.06032	eval-rmse:0.06018
# [1000]	train-rmse:0.06032	eval-rmse:0.06018
# [1100]	train-rmse:0.06032	eval-rmse:0.06018
# [1200]	train-rmse:0.06032	eval-rmse:0.06018
# [1242]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:03
# Train rmse: 0.06032
# Valid rmse: 0.06018
# [I 2025-07-28 01:37:17,840] Trial 58 finished with value: 0.06017944729229886 and parameters: {'learning_rate': 0.018150452098443327, 'max_depth': 10, 'min_child_weight': 69.77243110577157, 'colsample_bytree': 1.0, 'subsample': 0.612651234685618, 'reg_alpha': 14.02670949772724, 'reg_lambda': 1.118889674241306}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.66416	eval-rmse:3.66389
# [100]	train-rmse:0.24121	eval-rmse:0.24239
# [200]	train-rmse:0.06220	eval-rmse:0.06240
# [300]	train-rmse:0.06033	eval-rmse:0.06022
# [400]	train-rmse:0.06032	eval-rmse:0.06018
# [500]	train-rmse:0.06032	eval-rmse:0.06018
# [600]	train-rmse:0.06032	eval-rmse:0.06018
# [700]	train-rmse:0.06032	eval-rmse:0.06018
# [800]	train-rmse:0.06032	eval-rmse:0.06018
# [900]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:04
# Train rmse: 0.06032
# Valid rmse: 0.06018
# [I 2025-07-28 01:37:22,595] Trial 59 finished with value: 0.0601766345862064 and parameters: {'learning_rate': 0.027177815934076685, 'max_depth': 11, 'min_child_weight': 55.495592051249176, 'colsample_bytree': 1.0, 'subsample': 0.5142016809661618, 'reg_alpha': 7.4708359934608675, 'reg_lambda': 0.5898700526126628}. Best is trial 44 with value: 0.06016451525149665.
# [0]	train-rmse:3.67133	eval-rmse:3.67106
# [100]	train-rmse:0.29041	eval-rmse:0.29164
# [200]	train-rmse:0.06420	eval-rmse:0.06455
# [300]	train-rmse:0.06034	eval-rmse:0.06024
# [400]	train-rmse:0.06032	eval-rmse:0.06018
# [500]	train-rmse:0.06032	eval-rmse:0.06018
# [600]	train-rmse:0.06032	eval-rmse:0.06018
# [700]	train-rmse:0.06032	eval-rmse:0.06018
# [800]	train-rmse:0.06032	eval-rmse:0.06017
# [854]	train-rmse:0.06032	eval-rmse:0.06018
# Training time: 00:00:06
# Train rmse: 0.06032
# Valid rmse: 0.06017
# [I 2025-07-28 01:37:29,073] Trial 60 finished with value: 0.06017430074375235 and parameters: {'learning_rate': 0.025266493160746934, 'max_depth': 13, 'min_child_weight': 15.452689727729375, 'colsample_bytree': 1.0, 'subsample': 0.5618897082112804, 'reg_alpha': 0.00034447283344832106, 'reg_lambda': 0.33268565015082374}. Best is trial 44 with value: 0.06016451525149665.
# ✅ Message sent successfully.
